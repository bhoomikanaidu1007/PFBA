# %% [markdown]
# <a href="https://colab.research.google.com/github/bhoomikanaidu1007/PFBA/blob/main/Python__for_business_analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
product = input("Product name: ")
price = float(input("Unit price (₹): "))
qty = int(input("Quantity: "))
discount = float(input("Discount (%): "))
total_before = price * qty
discount_amt = total_before * discount / 100
total_after = total_before - discount_amt
print()
print("===== INVOICE =====")
print(f"Product : {product}")
print(f"Quantity : {qty}")
print(f"Price : ₹{price}")

print(f"Discount : {discount}% (-₹{discount_amt:.2f})")
print(f"TOTAL : ₹{total_after:.2f}")
print("===================")
# Out:
# Product name: Phone
# Unit price (₹): 25000
# Quantity: 4
# Discount (%): 12
#
# ===== INVOICE =====
# Product : Phone
# Quantity : 4
# Price : ₹25000.0
# Discount : 12.0% (-₹12000.00)
# TOTAL : ₹88000.00
# ...

# %% [markdown]
# Practice Question Day 2

# %%
prices = [500, 3500, 12000, 850, 7800]
for price in prices:
    if price < 1000:
        print(f"₹{price} → Budget")
    elif price <= 10000:
        print(f"₹{price} → Mid-range")
    else:
        print(f"₹{price} → Premium")
# Out:
# ₹500 → Budget
# ₹3500 → Mid-range
# ₹12000 → Premium
# ₹850 → Budget
# ₹7800 → Mid-range

# %% [markdown]
# Practice Que

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

operation = input("Choose operation (+, -, *, /): ")

if operation == "+":
    result = num1 + num2
elif operation == "-":
    result = num1 - num2
elif operation == "*":
    result = num1 * num2
elif operation == "/":
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error! Division by zero."
else:
    result = "Invalid operation"

print("Result:", result)
# Out:
# Enter first number: 3
# Enter second number: 9
# Choose operation (+, -, *, /): *
# Result: 27.0

# %% [markdown]
# Practice_Question_Day_3

# %%
df=pd.read_csv('sales_data_raw.csv')
print(df)
import pandas as pd

print("=" * 45)
print(f"Rows & Columns     : {df.shape[0]} rows, {df.shape[1]} columns")

missing = df.isnull().sum()
most_missing_col = missing.idxmax()
most_missing_val = missing.max()
print(f"Most Missing Values: '{most_missing_col}' ({most_missing_val} missing)")

if "Unit_Price" in df.columns:
    avg_price = df["Unit_Price"].mean()
    print(f"Avg Unit_Price     : {avg_price:.2f}")
else:
    print("Column 'Unit_Price' not found — check your column name.")

duplicate_count = df.duplicated().sum()
print(f"Duplicate Rows     : {duplicate_count}")
print("=" * 45)
# Out:
#        Order_ID  Order_Date Customer_Name Product_Category  Quantity  \
# 0     ORD-10524  2024-05-09   Sneha Kumar            Books         5
# 1     ORD-10254  2024-07-04   Arjun Verma         Clothing         2
# 2     ORD-10832  2024-06-08  Rahul Mishra      Electronics         1
# 3     ORD-10343  2024-07-30   Amit Mishra      Electronics         2
# 4     ORD-10601  2024-11-12   Arjun Kumar         Clothing         1
# ...         ...         ...           ...              ...       ...
# 1045  ORD-10778  2024-07-14  Arjun Mishra      Electronics         2
# 1046  ORD-10073  2024-08-21    Amit Kumar      Electronics         5
# 1047  ORD-10998  2024-08-05     Sneha Rao            Books         1
# 1048  ORD-10206  2024-07-07   Nisha Gupta      Electronics         1
# 1049  ORD-10867  2024-12-16     Karan Rao      Electronics         3
#
#       Unit_Price  Discount Region
# 0         592.79      20.0   West
# 1        1046.13      20.0  South
# ...

# %% [markdown]
# Practice 4

# %%
df = df.dropna(subset=['Unit_Price'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1020 entries, 0 to 1049
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1020 non-null   object
#  1   Order_Date        1020 non-null   object
#  2   Customer_Name     969 non-null    object
#  3   Product_Category  1020 non-null   object
#  4   Quantity          1020 non-null   int64
#  5   Unit_Price        1020 non-null   float64
#  6   Discount          937 non-null    float64
#  7   Region            1020 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 71.7+ KB

# %%
print(f"Rows after dropping: {len(df)}")
df['Discount'] = df['Discount'].fillna(0)
print(df.isnull().sum())
print(df.isnull().sum().sum())
# Out:
# Rows after dropping: 1020
# Order_ID            0
# Order_Date          0
# Customer_Name       0
# Product_Category    0
# Quantity            0
# Unit_Price          0
# Discount            0
# Region              0
# dtype: int64
# 0

# %% [markdown]
# Removing Duplicates

# %%
rows_before = len(df)
df = df.drop_duplicates()
rows_after  = len(df)

print(f"Removed {rows_before - rows_after} duplicate rows")
# Out:
# Removed 50 duplicate rows

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
print(df['Order_Date'].dtype)
df['Month'] = df['Order_Date'].dt.month
month_names = {
    1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr',
    5:'May', 6:'Jun', 7:'Jul', 8:'Aug',
    9:'Sep', 10:'Oct', 11:'Nov', 12:'Dec'
}

df['Month_Name'] = df['Month'].map(month_names)

df[['Order_Date', 'Quantity', 'Unit_Price', 'Discount', 'Revenue', 'Month', 'Month_Name']].head(8)

print(f"Total Revenue : ₹{df['Revenue'].sum():,.2f}")
print(f"Average Order : ₹{df['Revenue'].mean():,.2f}")
print(f"Largest Order : ₹{df['Revenue'].max():,.2f}")
print(f"Smallest Order: ₹{df['Revenue'].min():,.2f}")
# Out:
# datetime64[ns]
# Total Revenue : ₹26,331,199.25
# Average Order : ₹27,145.57
# Largest Order : ₹233,380.80
# Smallest Order: ₹172.74
# /tmp/ipykernel_803/1983235138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Order_Date'] = pd.to_datetime(df['Order_Date'])
# /tmp/ipykernel_803/1983235138.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month'] = df['Order_Date'].dt.month
# /tmp/ipykernel_803/1983235138.py:10: SettingWithCopyWarning:
# ...

# %% [markdown]
# Practice question day 4

# %%
data = {
    'Order_ID': [1, 2, 3, 4, 5],
    'Order_Date': ['2024-01-15', '2024-02-20', '2024-01-30', '2024-03-10', '2024-02-25'],
    'Quantity': [10, 5, 8, 3, 7],
    'Unit_Price': [100, 250, 150, 400, 200]
}
df = pd.DataFrame(data)

df['Revenue'] = df['Quantity'] * df['Unit_Price']
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Month'] = df['Order_Date'].dt.month

total_revenue = df['Revenue'].sum()
print("Total Revenue:", total_revenue)

max_revenue_idx = df['Revenue'].idxmax()
month_highest = df.loc[max_revenue_idx, 'Month']
print("Month with Highest Single-Order Revenue:", month_highest)

print("\nUpdated DataFrame:")
print(df)
# Out:
# Total Revenue: 6050
# Month with Highest Single-Order Revenue: 2
#
# Updated DataFrame:
#    Order_ID Order_Date  Quantity  Unit_Price  Revenue  Month
# 0         1 2024-01-15        10         100     1000      1
# 1         2 2024-02-20         5         250     1250      2
# 2         3 2024-01-30         8         150     1200      1
# 3         4 2024-03-10         3         400     1200      3
# 4         5 2024-02-25         7         200     1400      2
